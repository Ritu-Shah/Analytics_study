# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritu-Shah/Analytics_study/blob/main/ritu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

titanic = pd.read_csv('./drive/MyDrive/Colab Notebooks/titanic.csv')

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
null = titanic.isnull().sum()
null
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe().transpose()
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
titanic.rename(columns={"Survived": "2urvived"})
# Out:
#      PassengerId  2urvived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.loc[(titanic['Name'].str.contains("John")), :]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 8              9         1       3
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 172          173         1       3
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 302          303         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# ...

# %%
titanic['Fare'] = titanic['Fare'].astype(int)

# %%
titanic['Fare']
# Out:
# 0       7
# 1      71
# 2       7
# 3      53
# 4       8
#        ..
# 886    13
# 887    30
# 888    23
# 889    30
# 890     7
# Name: Fare, Length: 891, dtype: int64

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 438          439         0       1                   Fortune, Mr. Mark
# 88            89         1       1          Fortune, Miss. Mabel Helen
# ..           ...       ...     ...                                 ...
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 466          467         0       2               Campbell, Mr. William
# 271          272         1       3        Tornquist, Mr. William Henry
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# 597          598         0       3                 Johnson, Mr. Alfred
#
#         Sex   Age  SibSp  Parch    Ticket  Fare        Cabin Embarked
# ...

# %% [markdown]
# #Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Countplot:

# %%
sns.countplot(x = 'Pclass', hue = 'Survived', data = titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# Histplot

# %%
fig = plt.figure(figsize = (10, 4))

ax1 = fig.add_subplot(1, 2, 1)
sns.histplot(data = titanic, x = 'Age', hue = 'Survived', color = 'blue')

#Boxplot
ax1 = fig.add_subplot(1, 2, 2)
sns.boxplot(titanic['Age'])
# Out:
# <Axes: >

# %% [markdown]
# Scatter Plot:

# %%
sns.scatterplot(x = 'Age', y = 'Fare', hue = 'Survived', data = titanic)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x = 'Age', y = 'Fare', hue = 'Pclass', data = titanic)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x = 'Age', y = 'Fare', hue = 'Sex', data = titanic)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
ax1 = fig.add_subplot(1, 2, 2)
sns.boxplot(data = titanic, x = 'Age', hue = 'Survived', color = 'green')
# Out:
# <Axes: xlabel='Age'>

# %%
pip install pillow
