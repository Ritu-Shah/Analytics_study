# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritu-Shah/Analytics_study/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Library for pulling data from particular storage
import pandas as pd
import random
import string
from datetime import datetime, timedelta

# Generate fake data
num_records = 255

park_names = ['Magical Kingdom', 'Animal Kingdom', 'Hollywood Studio', 'EPCOT']
ticket_prices = [random.uniform(50, 150) for _ in range(num_records)]
visitor_counts = [random.randint(1000, 100000) for _ in range(num_records)]
discounts = [random.uniform(0, 75) for _ in range(num_records)]
revenues = [random.uniform(50000, 1000000) for _ in range(num_records)]
profit = [random.uniform(0, 50000) for _ in range(num_records)]
expenditures = [random.uniform(40000, 800000) for _ in range(num_records)]
rides = ['Ride A', 'Ride B', 'Ride C', 'Ride D', 'Ride E']
geographical_locations = ['Florida', 'California']
ages = [random.randint(5, 80) for _ in range(num_records)]
genders = ['Male', 'Female', 'Other'] # You can customize the gender categories


# Generate a single date for the fake data
start_date = datetime(2022, 8, 15)
end_date = datetime(2023, 8, 15)
dates = [start_date + timedelta(days=i) for i in range(num_records)]

# Create a DataFrame for fake data
dl_data = pd.DataFrame({
    'Date': dates,
    'Park Name': [random.choice(park_names) for _ in range(num_records)],
    'Ticket Price': ticket_prices,
    'Visitor Count': visitor_counts,
    'Discount': discounts,
    'Revenue': revenues,
    'profit': profit,
    'Expenditure': expenditures,
    'Ride': [random.choice(rides) for _ in range(num_records)],
    'Geographical Location': [random.choice(geographical_locations) for _ in range(num_records)],
    'Age': ages,
    'Genders': [random.choice(genders) for _ in range(num_records)]
})

from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
stock_df = pd.read_csv('./drive/MyDrive/Colab Notebooks/stock_data.csv')
# Out:
# Mounted at /content/drive

# %%
start_date = datetime(2022, 8, 15)
end_date = datetime(2023, 8, 15)
dates = [start_date + timedelta(days=i) for i in range(num_records)]

# %%
tickerSymbol = 'MSFT'
dl_data
# Out:
#           Date        Park Name  Ticket Price  Visitor Count   Discount  \
# 0   2022-08-15            EPCOT     57.980164          77646   6.626719
# 1   2022-08-16   Animal Kingdom    102.425962          20716  40.218337
# 2   2022-08-17            EPCOT    108.753801          12158  49.616904
# 3   2022-08-18   Animal Kingdom     97.311374          80087  30.139179
# 4   2022-08-19  Magical Kingdom    100.274892          39360  12.818961
# ..         ...              ...           ...            ...        ...
# 250 2023-04-22            EPCOT     59.328464          64695  63.471940
# 251 2023-04-23            EPCOT     86.367656          28339  62.673904
# 252 2023-04-24  Magical Kingdom     71.350980          81543  40.729570
# 253 2023-04-25            EPCOT    103.328129          59136   6.730343
# 254 2023-04-26  Magical Kingdom    105.443847          99970   4.651757
#
#            Revenue        profit    Expenditure    Ride Geographical Location  \
# ...

# %%
dl_data.to_csv('./drive/MyDrive/Colab Notebooks/DFD1.csv', index=False)

# %%
import pandas as pd
from datetime import datetime, timedelta

# Load your original Stock_data and Fake_data
stock_df = pd.read_csv('./drive/MyDrive/Colab Notebooks/stock_data.csv')
dl_data = pd.DataFrame({
    'Date': dates,
    'Park Name': [random.choice(park_names) for _ in range(num_records)],
    'Ticket Price': ticket_prices,
    'Visitor Count': visitor_counts,
    'Discount': discounts,
    'Revenue': revenues,
    'profit': profit,
    'Expenditure': expenditures,
    'Ride': [random.choice(rides) for _ in range(num_records)],
    'Geographical Location': [random.choice(geographical_locations) for _ in range(num_records)],
    'Age': ages,
    'Genders': [random.choice(genders) for _ in range(num_records)]
})

# Convert the 'Date' column to datetime type in both datasets
stock_df['Date'] = pd.to_datetime(stock_df['Date'])
dl_data['Date'] = pd.to_datetime(dl_data['Date'])

# Create a complete date range using the 'Date' column from stock_data
complete_date_range = pd.date_range(start=stock_df['Date'].min(), end=stock_df['Date'].max(), freq='D')

# Create a DataFrame with the complete date range
merged_data = pd.DataFrame({'Date': complete_date_range})

# Merge the stock_data and fake_data on the 'Date' column
merged_data = merged_data.merge(stock_df, on='Date', how='left')
merged_data = merged_data.merge(dl_data, on='Date', how='left')

# Display the merged data
print(merged_data)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-01-09  111.790001  112.589996  110.029999  112.529999  112.529999
# 1   2022-01-10         NaN         NaN         NaN         NaN         NaN
# 2   2022-01-11  107.699997  108.839996  105.639999  106.000000  106.000000
# 3   2022-01-12   97.870003   98.839996   96.580002   98.589996   98.589996
# 4   2022-01-13         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 693 2023-12-03         NaN         NaN         NaN         NaN         NaN
# 694 2023-12-04  101.250000  102.220001   97.699997   97.940002   97.940002
# 695 2023-12-05   92.339996   92.879997   91.239998   91.989998   91.989998
# 696 2023-12-06   92.250000   93.230003   91.769997   93.139999   93.139999
# 697 2023-12-07   90.110001   90.709999   89.570000   90.150002   90.150002
#
# ...

# %%
tickerSymbol = 'MSFT'
merged_data
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-01-09  111.790001  112.589996  110.029999  112.529999  112.529999
# 1   2022-01-10         NaN         NaN         NaN         NaN         NaN
# 2   2022-01-11  107.699997  108.839996  105.639999  106.000000  106.000000
# 3   2022-01-12   97.870003   98.839996   96.580002   98.589996   98.589996
# 4   2022-01-13         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 693 2023-12-03         NaN         NaN         NaN         NaN         NaN
# 694 2023-12-04  101.250000  102.220001   97.699997   97.940002   97.940002
# 695 2023-12-05   92.339996   92.879997   91.239998   91.989998   91.989998
# 696 2023-12-06   92.250000   93.230003   91.769997   93.139999   93.139999
# 697 2023-12-07   90.110001   90.709999   89.570000   90.150002   90.150002
#
# ...

# %%
merged_data.to_csv('./drive/MyDrive/Colab Notebooks/DFD2.csv', index=False)

# %%
import pandas as pd
from datetime import datetime, timedelta

# Load your original Stock_data and Fake_data
stock_df = pd.read_csv('./drive/MyDrive/Colab Notebooks/stock_data.csv')
dl_data = pd.DataFrame({
    'Date': dates,
    'Park Name': [random.choice(park_names) for _ in range(num_records)],
    'Ticket Price': ticket_prices,
    'Visitor Count': visitor_counts,
    'Discount': discounts,
    'Revenue': revenues,
    'profit': profit,
    'Expenditure': expenditures,
    'Ride': [random.choice(rides) for _ in range(num_records)],
    'Geographical Location': [random.choice(geographical_locations) for _ in range(num_records)],
    'Age': ages,
    'Genders': [random.choice(genders) for _ in range(num_records)]
})

# Convert the 'Date' column to datetime type in both datasets
stock_df['Date'] = pd.to_datetime(stock_df['Date'])
dl_data['Date'] = pd.to_datetime(dl_data['Date'])

# Create a complete date range using the 'Date' column from stock_data
complete_date_range = pd.date_range(start=stock_df['Date'].min(), end=stock_df['Date'].max(), freq='D')

# Create a DataFrame with the complete date range
merged_data = pd.DataFrame({'Date': complete_date_range})

# Merge the stock_data and fake_data on the 'Date' column
merged_data = merged_data.merge(stock_df, on='Date', how='left')
merged_data = merged_data.merge(dl_data, on='Date', how='left')

# Merge the two DataFrames based on the 'date' column
Disney_merged_data1 = pd.merge(dl_data, stock_df, on='Date', how='inner')
# Out:
# <ipython-input-2-cbe22894706f>:22: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   stock_df['Date'] = pd.to_datetime(stock_df['Date'])

# %%
Disney_merged_data1.columns
# Out:
# Index(['Date', 'Park Name', 'Ticket Price', 'Visitor Count', 'Discount',
#        'Revenue', 'profit', 'Expenditure', 'Ride', 'Geographical Location',
#        'Age', 'Genders', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume'],
#       dtype='object')

# %%
tickerSymbol = 'MSFT'
Disney_merged_data1
# Out:
#           Date         Park Name  Ticket Price  Visitor Count   Discount  \
# 0   2022-08-15   Magical Kingdom     57.980164          77646   6.626719
# 1   2022-08-16             EPCOT    102.425962          20716  40.218337
# 2   2022-08-17  Hollywood Studio    108.753801          12158  49.616904
# 3   2022-08-18  Hollywood Studio     97.311374          80087  30.139179
# 4   2022-08-19             EPCOT    100.274892          39360  12.818961
# ..         ...               ...           ...            ...        ...
# 139 2023-04-20   Magical Kingdom     54.534134          72316  71.932108
# 140 2023-04-21             EPCOT    104.419554          42535  72.657716
# 141 2023-04-24  Hollywood Studio     71.350980          81543  40.729570
# 142 2023-04-25   Magical Kingdom    103.328129          59136   6.730343
# 143 2023-04-26  Hollywood Studio    105.443847          99970   4.651757
#
#            Revenue        profit    Expenditure    Ride Geographical Location  \
# ...

# %%
merged_data.to_csv('./drive/MyDrive/Colab Notebooks/DFD3.csv', index=False)

# %%
Disney_merged_data1.to_csv('./drive/MyDrive/Colab Notebooks/DFD4.csv', index=False)

# %% [markdown]
# for assignment practice

# %%
Disney_merged_data1.shape
# Out:
# (144, 18)

# %%
merged_data.shape
# Out:
# (698, 18)

# %%
dl_data.shape
# Out:
# (255, 12)

# %%
stock_df.shape
# Out:
# (252, 7)

# %%
merged_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Park Name', 'Ticket Price', 'Visitor Count', 'Discount', 'Revenue',
#        'profit', 'Expenditure', 'Ride', 'Geographical Location', 'Age',
#        'Genders'],
#       dtype='object')

# %%
Disney_merged_data1.columns
# Out:
# Index(['Date', 'Park Name', 'Ticket Price', 'Visitor Count', 'Discount',
#        'Revenue', 'profit', 'Expenditure', 'Ride', 'Geographical Location',
#        'Age', 'Genders', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume'],
#       dtype='object')

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 698 entries, 0 to 697
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   698 non-null    datetime64[ns]
#  1   Open                   252 non-null    float64
#  2   High                   252 non-null    float64
#  3   Low                    252 non-null    float64
#  4   Close                  252 non-null    float64
#  5   Adj Close              252 non-null    float64
#  6   Volume                 252 non-null    float64
#  7   Park Name              255 non-null    object
#  8   Ticket Price           255 non-null    float64
#  9   Visitor Count          255 non-null    float64
#  10  Discount               255 non-null    float64
#  11  Revenue                255 non-null    float64
#  12  profit                 255 non-null    float64
#  13  Expenditure            255 non-null    float64
# ...

# %%
Disney_merged_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   144 non-null    datetime64[ns]
#  1   Park Name              144 non-null    object
#  2   Ticket Price           144 non-null    float64
#  3   Visitor Count          144 non-null    int64
#  4   Discount               144 non-null    float64
#  5   Revenue                144 non-null    float64
#  6   profit                 144 non-null    float64
#  7   Expenditure            144 non-null    float64
#  8   Ride                   144 non-null    object
#  9   Geographical Location  144 non-null    object
#  10  Age                    144 non-null    int64
#  11  Genders                144 non-null    object
#  12  Open                   144 non-null    float64
#  13  High                   144 non-null    float64
# ...

# %%
null = merged_data.isnull().sum()
null
# Out:
# Date                       0
# Open                     446
# High                     446
# Low                      446
# Close                    446
# Adj Close                446
# Volume                   446
# Park Name                443
# Ticket Price             443
# Visitor Count            443
# Discount                 443
# Revenue                  443
# profit                   443
# Expenditure              443
# Ride                     443
# Geographical Location    443
# Age                      443
# Genders                  443
# dtype: int64

# %%
null = Disney_merged_data1.isnull().sum()
null
# Out:
# Date                     0
# Park Name                0
# Ticket Price             0
# Visitor Count            0
# Discount                 0
# Revenue                  0
# profit                   0
# Expenditure              0
# Ride                     0
# Geographical Location    0
# Age                      0
# Genders                  0
# Open                     0
# High                     0
# Low                      0
# Close                    0
# Adj Close                0
# Volume                   0
# dtype: int64

# %%
merged_data.sort_values(by='Ticket Price',ascending=False)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 269 2022-10-05         NaN         NaN         NaN         NaN         NaN
# 449 2023-04-03         NaN         NaN         NaN         NaN         NaN
# 404 2023-02-17  105.029999  105.800003  103.879997  105.220001  105.220001
# 333 2022-12-08         NaN         NaN         NaN         NaN         NaN
# 350 2022-12-25         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 693 2023-12-03         NaN         NaN         NaN         NaN         NaN
# 694 2023-12-04  101.250000  102.220001   97.699997   97.940002   97.940002
# 695 2023-12-05   92.339996   92.879997   91.239998   91.989998   91.989998
# 696 2023-12-06   92.250000   93.230003   91.769997   93.139999   93.139999
# 697 2023-12-07   90.110001   90.709999   89.570000   90.150002   90.150002
#
# ...
