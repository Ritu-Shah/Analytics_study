# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritu-Shah/Analytics_study/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

Cust_bank = pd.read_csv('./drive/MyDrive/Colab Notebooks/Customer bank Churn.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

Cust_bank1 = pd.read_csv('./drive/MyDrive/Colab Notebooks/Bank_marketing.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
Cust_bank['identifier'] = Cust_bank.index
Cust_bank1['identifier'] = Cust_bank1.index

# %%
merged_Bnak_data = pd.merge(Cust_bank, Cust_bank1, on='identifier')

# %%
Cust_bank.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-7f2f0141239c> in <cell line: 1>()
# ----> 1 Cust_bank.shape
#
# NameError: name 'Cust_bank' is not defined

# %%
Cust_bank1.shape
# Out:
# (41188, 22)

# %%
Cust_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
Cust_bank1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
Cust_bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  identifier
# ...

# %%
merged_Bnak_data.columns
# Out:
# Index(['age_x', 'job_x', 'marital_x', 'education_x', 'default_x', 'housing_x',
#        'loan_x', 'contact_x', 'month_x', 'day_of_week_x', 'duration_x',
#        'campaign_x', 'pdays_x', 'previous_x', 'poutcome_x', 'emp.var.rate_x',
#        'cons.price.idx_x', 'cons.conf.idx_x', 'euribor3m_x', 'nr.employed_x',
#        'y_x', 'identifier', 'age_y', 'job_y', 'marital_y', 'education_y',
#        'default_y', 'housing_y', 'loan_y', 'contact_y', 'month_y',
#        'day_of_week_y', 'duration_y', 'campaign_y', 'pdays_y', 'previous_y',
#        'poutcome_y', 'emp.var.rate_y', 'cons.price.idx_y', 'cons.conf.idx_y',
#        'euribor3m_y', 'nr.employed_y', 'y_y'],
#       dtype='object')

# %%
merged_Bnak_data.describe().transpose()
# Out:
#                     count          mean           std       min        25%  \
# age_x             41188.0     40.024060     10.421250    17.000     32.000
# duration_x        41188.0    258.285010    259.279249     0.000    102.000
# campaign_x        41188.0      2.567593      2.770014     1.000      1.000
# pdays_x           41188.0    962.475454    186.910907     0.000    999.000
# previous_x        41188.0      0.172963      0.494901     0.000      0.000
# emp.var.rate_x    41188.0      0.081886      1.570960    -3.400     -1.800
# cons.price.idx_x  41188.0     93.575664      0.578840    92.201     93.075
# cons.conf.idx_x   41188.0    -40.502600      4.628198   -50.800    -42.700
# euribor3m_x       41188.0      3.621291      1.734447     0.634      1.344
# nr.employed_x     41188.0   5167.035911     72.251528  4963.600   5099.100
# identifier        41188.0  20593.500000  11890.095780     0.000  10296.750
# ...

# %%
Cust_bank.head
# Out:
# <bound method NDFrame.head of        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
import yfinance as yf
tickerSymbol = 'MSFT'
tickerData = yf.Ticker(tickerSymbol)
tickerDf = tickerData.history(period='1d', start='2010-1-1', end='2020-1-25')
tickerDf
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00   23.321030   23.686611   23.298180   23.572367
# 2010-01-05 00:00:00-05:00   23.496205   23.686612   23.336262   23.579983
# 2010-01-06 00:00:00-05:00   23.519050   23.671376   23.244865   23.435272
# 2010-01-07 00:00:00-05:00   23.328647   23.381962   22.993532   23.191555
# 2010-01-08 00:00:00-05:00   23.062080   23.519055   23.031614   23.351498
# ...                               ...         ...         ...         ...
# 2020-01-17 00:00:00-05:00  162.001989  162.050374  160.076383  161.692352
# 2020-01-21 00:00:00-05:00  161.285923  162.747066  161.044014  161.111755
# 2020-01-22 00:00:00-05:00  161.982628  162.069727  160.318290  160.337646
# 2020-01-23 00:00:00-05:00  160.811784  161.402044  159.921558  161.324631
# 2020-01-24 00:00:00-05:00  162.089057  162.108414  159.128087  159.698990
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
tickerDf.head
# Out:
# <bound method NDFrame.head of                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00   23.321030   23.686611   23.298180   23.572367
# 2010-01-05 00:00:00-05:00   23.496205   23.686612   23.336262   23.579983
# 2010-01-06 00:00:00-05:00   23.519050   23.671376   23.244865   23.435272
# 2010-01-07 00:00:00-05:00   23.328647   23.381962   22.993532   23.191555
# 2010-01-08 00:00:00-05:00   23.062080   23.519055   23.031614   23.351498
# ...                               ...         ...         ...         ...
# 2020-01-17 00:00:00-05:00  162.001989  162.050374  160.076383  161.692352
# 2020-01-21 00:00:00-05:00  161.285923  162.747066  161.044014  161.111755
# 2020-01-22 00:00:00-05:00  161.982628  162.069727  160.318290  160.337646
# 2020-01-23 00:00:00-05:00  160.811784  161.402044  159.921558  161.324631
# 2020-01-24 00:00:00-05:00  162.089057  162.108414  159.128087  159.698990
#
# ...

# %%
import yfinance as yf
tickerSymbol = 'MSFT'
tickerData = yf.Ticker(tickerSymbol)
tickerDf = tickerData.history(period='1week', start='2010-1-1', end='2023-1-25')
tickerDf
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00   23.321037   23.686618   23.298188   23.572374
# 2010-01-05 00:00:00-05:00   23.496203   23.686610   23.336260   23.579981
# 2010-01-06 00:00:00-05:00   23.519054   23.671380   23.244869   23.435276
# 2010-01-07 00:00:00-05:00   23.328649   23.381964   22.993534   23.191557
# 2010-01-08 00:00:00-05:00   23.062086   23.519061   23.031620   23.351503
# ...                               ...         ...         ...         ...
# 2023-01-18 00:00:00-05:00  240.440834  241.247045  234.419111  234.707748
# 2023-01-19 00:00:00-05:00  232.687245  234.419117  229.601729  230.845886
# 2023-01-20 00:00:00-05:00  233.762206  239.614726  233.413836  239.097153
# 2023-01-23 00:00:00-05:00  239.973028  244.023996  238.529794  241.446106
# 2023-01-24 00:00:00-05:00  241.366487  242.809706  239.316118  240.908630
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://finance.yahoo.com/quote/DIS/key-statistics?p=DIS'
response = requests.get(url)
if response.status_code == 100:
  soup = BeautifulSoup(response.content, 'html.parser')
  park_names = [park.text for park in soup.find_all('h2', class_='park-name')]
  ticket_prices = [price.text for price in soup.find_all('span', class_='ticket-price')]
  visitor_counts = [int(count.text) for count in soup.find_all('div', class_='visitor-count')]
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://finance.yahoo.com/quote/DIS/key-statistics?p=DIS'
response = requests.get(url)
if response.status_code == 100:
  soup = BeautifulSoup(response.content, 'html.parser')
  attribute_names = [item.get_text(strip=True) for item in soup.find_all('td', class_='C(black)')]
  attribute_values = [item.get_text(strip=True) for item in soup.find_all('td', class_='Ta(end)')]
  data = {
        'Attribute': attribute_names,
        'Value': attribute_values
    }

# %%
Disneydf = pd.read_csv('https://finance.yahoo.com/quote/DIS/key-statistics?p=DIS')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-30-2e85a26d0f29> in <cell line: 1>()
# ----> 1 Disneydf = pd.read_csv('https://finance.yahoo.com/quote/DIS/key-statistics?p=DIS')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# Fake data set

# %%
import pandas as pd
import random
import string

# Generate fake data
num_records = 100

park_names = ['Disney', 'Universal', 'Efteling', 'Others']
ticket_prices = [random.uniform(50, 150) for _ in range(num_records)]
visitor_counts = [random.randint(1000, 100000) for _ in range(num_records)]
discounts = [random.uniform(0, 0.5) for _ in range(num_records)]
revenues = [random.uniform(50000, 1000000) for _ in range(num_records)]
expenditures = [random.uniform(40000, 800000) for _ in range(num_records)]
rides = ['Ride A', 'Ride B', 'Ride C', 'Ride D', 'Ride E']
geographical_locations = ['Florida', 'California', 'Other']
# Create a DataFrame
data = {
    'Park Name': [random.choice(park_names) for _ in range(num_records)],
    'Ticket Price': ticket_prices,
    'Visitor Count': visitor_counts,
    'Discount': discounts,
    'Revenue': revenues,
    'Expenditure': expenditures,
    'Ride': [random.choice(rides) for _ in range(num_records)],
    'Geographical Location': [random.choice(geographical_locations) for _ in range(num_records)],
}

df = pd.DataFrame(data)

# Display the generated fake dataset
print(df.head())
# Out:
#    Park Name  Ticket Price  Visitor Count  Discount        Revenue  \
# 0   Efteling     73.795617           8051  0.095237  356970.493772
# 1  Universal    148.371186          52946  0.150125  539300.987975
# 2     Disney     66.244642          77895  0.282265  557072.392880
# 3     Disney     92.554734          20019  0.039266  292418.728458
# 4     Disney     88.803937          80480  0.299339  636089.738610
#
#      Expenditure    Ride Geographical Location
# 0  179552.686911  Ride B                 Other
# 1  604669.096750  Ride D                 Other
# 2  722727.701988  Ride D            California
# 3  487190.111945  Ride D                 Other
# 4  397293.424385  Ride D                 Other

# %%
df.head
# Out:
# <bound method NDFrame.head of     Park Name  Ticket Price  Visitor Count  Discount        Revenue  \
# 0    Efteling     73.795617           8051  0.095237  356970.493772
# 1   Universal    148.371186          52946  0.150125  539300.987975
# 2      Disney     66.244642          77895  0.282265  557072.392880
# 3      Disney     92.554734          20019  0.039266  292418.728458
# 4      Disney     88.803937          80480  0.299339  636089.738610
# ..        ...           ...            ...       ...            ...
# 95   Efteling    107.459194          67777  0.008021  408417.513673
# 96     Disney     83.214012          19721  0.154968  818107.802547
# 97  Universal     68.147820          22765  0.452087  179855.873084
# 98  Universal    137.214568          22188  0.201448  113318.023992
# 99   Efteling    112.295166          70599  0.298386  511706.444659
#
#       Expenditure    Ride Geographical Location
# 0   179552.686911  Ride B                 Other
# ...

# %%
df.to_csv('fake_data.csv', index=False)

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /content

# %%
import pandas as pd
tickerSymbol = 'MSFT'
df
# Out:
#     Park Name  Ticket Price  Visitor Count  Discount        Revenue  \
# 0    Efteling     73.795617           8051  0.095237  356970.493772
# 1   Universal    148.371186          52946  0.150125  539300.987975
# 2      Disney     66.244642          77895  0.282265  557072.392880
# 3      Disney     92.554734          20019  0.039266  292418.728458
# 4      Disney     88.803937          80480  0.299339  636089.738610
# ..        ...           ...            ...       ...            ...
# 95   Efteling    107.459194          67777  0.008021  408417.513673
# 96     Disney     83.214012          19721  0.154968  818107.802547
# 97  Universal     68.147820          22765  0.452087  179855.873084
# 98  Universal    137.214568          22188  0.201448  113318.023992
# 99   Efteling    112.295166          70599  0.298386  511706.444659
#
#       Expenditure    Ride Geographical Location
# 0   179552.686911  Ride B                 Other
# 1   604669.096750  Ride D                 Other
# ...

# %%
import pandas as pd
tickerSymbol = 'MSFT'
df
# Out:
#     Park Name  Ticket Price  Visitor Count  Discount        Revenue  \
# 0    Efteling     73.795617           8051  0.095237  356970.493772
# 1   Universal    148.371186          52946  0.150125  539300.987975
# 2      Disney     66.244642          77895  0.282265  557072.392880
# 3      Disney     92.554734          20019  0.039266  292418.728458
# 4      Disney     88.803937          80480  0.299339  636089.738610
# ..        ...           ...            ...       ...            ...
# 95   Efteling    107.459194          67777  0.008021  408417.513673
# 96     Disney     83.214012          19721  0.154968  818107.802547
# 97  Universal     68.147820          22765  0.452087  179855.873084
# 98  Universal    137.214568          22188  0.201448  113318.023992
# 99   Efteling    112.295166          70599  0.298386  511706.444659
#
#       Expenditure    Ride Geographical Location
# 0   179552.686911  Ride B                 Other
# 1   604669.096750  Ride D                 Other
# ...

# %%
df.columns
# Out:
# Index(['Park Name', 'Ticket Price', 'Visitor Count', 'Discount', 'Revenue',
#        'Expenditure', 'Ride', 'Geographical Location'],
#       dtype='object')

# %%
import pandas as pd
import random
import string
from datetime import datetime, timedelta

# Generate fake data
num_records = 100

park_names = ['Disney', 'Universal', 'Efteling', 'Others']
ticket_prices = [random.uniform(50, 150) for _ in range(num_records)]
visitor_counts = [random.randint(1000, 100000) for _ in range(num_records)]
discounts = [random.uniform(0, 0.5) for _ in range(num_records)]
revenues = [random.uniform(50000, 1000000) for _ in range(num_records)]
expenditures = [random.uniform(40000, 800000) for _ in range(num_records)]
rides = ['Ride A', 'Ride B', 'Ride C', 'Ride D', 'Ride E']
geographical_locations = ['Florida', 'California', 'Other']

# Generate a single date for the fake data
start_date = datetime(2023, 1, 1)
dates = [start_date + timedelta(days=i) for i in range(num_records)]

# Generate synthetic customer IDs
customer_ids = ["".join(random.choice(string.ascii_uppercase + string.digits) for _ in range(6)) for _ in range(num_records)]

# Create a DataFrame for fake data
fake_data = pd.DataFrame({
    'Customer ID': customer_ids,
    'Date': dates,
    'Park Name': [random.choice(park_names) for _ in range(num_records)],
    'Ticket Price': ticket_prices,
    'Visitor Count': visitor_counts,
    'Discount': discounts,
    'Revenue': revenues,
    'Expenditure': expenditures,
    'Ride': [random.choice(rides) for _ in range(num_records)],
    'Geographical Location': [random.choice(geographical_locations) for _ in range(num_records)]
})
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
stock_df = pd.read_csv('./drive/MyDrive/Colab Notebooks/stock_data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
stock_df = pd.read_csv('./drive/MyDrive/Colab Notebooks/stock_data.csv')
# Out:
# Mounted at /content/drive

# %%
# Generate synthetic keys for merging
fake_data['synthetic_key'] = fake_data.index
stock_df['synthetic_key'] = stock_df.index

# Merge datasets based on the synthetic key
Disney_merged_data = pd.merge(fake_data, stock_df, on='synthetic_key', how='inner')

# Display the merged data
print(Disney_merged_data)
# Out:
#    Customer ID     Date_x  Park Name  Ticket Price  Visitor Count  Discount  \
# 0       DXSVZC 2023-01-01     Others    105.733878          13310  0.263021
# 1       R2H2W1 2023-01-02  Universal    146.127414          84632  0.320079
# 2       VCN2CN 2023-01-03  Universal    141.678706          30807  0.250152
# 3       OIGW64 2023-01-04  Universal    110.053781          23427  0.248490
# 4       M06BEV 2023-01-05   Efteling    133.636001          67337  0.356652
# ..         ...        ...        ...           ...            ...       ...
# 95      J4CW4S 2023-04-06     Disney    140.257518          54120  0.357882
# 96      Q14CJD 2023-04-07     Disney    129.472849          88693  0.248133
# 97      9A53TO 2023-04-08     Others    136.414759          11568  0.269965
# 98      XLKPSI 2023-04-09     Disney    110.172829          26689  0.174600
# 99      WXYKJV 2023-04-10     Others    131.414317          84117  0.185841
#
# ...

# %%
fake_data.columns
# Out:
# Index(['Customer ID', 'Date', 'Park Name', 'Ticket Price', 'Visitor Count',
#        'Discount', 'Revenue', 'Expenditure', 'Ride', 'Geographical Location',
#        'synthetic_key'],
#       dtype='object')

# %%
import pandas as pd
tickerSymbol = 'MSFT'
Disney_merged_data
# Out:
#    Customer ID     Date_x  Park Name  Ticket Price  Visitor Count  Discount  \
# 0       DXSVZC 2023-01-01     Others    105.733878          13310  0.263021
# 1       R2H2W1 2023-01-02  Universal    146.127414          84632  0.320079
# 2       VCN2CN 2023-01-03  Universal    141.678706          30807  0.250152
# 3       OIGW64 2023-01-04  Universal    110.053781          23427  0.248490
# 4       M06BEV 2023-01-05   Efteling    133.636001          67337  0.356652
# ..         ...        ...        ...           ...            ...       ...
# 95      J4CW4S 2023-04-06     Disney    140.257518          54120  0.357882
# 96      Q14CJD 2023-04-07     Disney    129.472849          88693  0.248133
# 97      9A53TO 2023-04-08     Others    136.414759          11568  0.269965
# 98      XLKPSI 2023-04-09     Disney    110.172829          26689  0.174600
# 99      WXYKJV 2023-04-10     Others    131.414317          84117  0.185841
#
# ...

# %%
# Disney_merged_data.to_csv("C:\\Users\\ritushah\\Downloads.csv")
Disney_merged_data.to_csv('./drive/MyDrive/Colab Notebooks/DFD.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Disney_merged_data.columns
# Out:
# Index(['Customer ID', 'Date_x', 'Park Name', 'Ticket Price', 'Visitor Count',
#        'Discount', 'Revenue', 'Expenditure', 'Ride', 'Geographical Location',
#        'synthetic_key', 'Date_y', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume'],
#       dtype='object')
